# %%
# preparation - import libraries
import pandas as pd
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import matplotlib.pyplot as plt
import os
import logging
import requests
import bs4

# %%
## Setup chrome options

chrome_options = Options()
chrome_options.add_argument("--headless") # Ensure GUI is off
chrome_options.add_argument("--no-sandbox")

# %%
# Install Chrome driver manager
service = Service(executable_path=ChromeDriverManager().install())

# %%
driver = webdriver.Chrome()

# %%
# Get the page's contents

page_url = "https://en.wikipedia.org/wiki/Key_events_of_the_20th_century"
driver.get(page_url)

# %%
# find elements 

toc_item = driver.find_element(
    By.CSS_SELECTOR,
    "li#toc-Historic_events_in_the_20th_century"
)

# %%
print (toc_item)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="cc4527a37bd51a59eb1266b91fd4df5e", element="f.970CEF9A394C01787AEBDDFB51F4E944.d.0FFC925292C9BB5228FEE4309D205DC2.e.103")>

# %%
# print outcome as text
print(toc_item.text)
# Out:
# Historic events in the 20th century
# Toggle Historic events in the 20th century subsection

# %%
# find sub elements
sub_items = toc_item.find_elements(
    By.CSS_SELECTOR,
    "ul.vector-toc-list li a.vector-toc-link"
)

# %%
for item in sub_items:
    print(item.text, "->", item.get_attribute("href"))
# Out:
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#World_at_the_beginning_of_the_century
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#%22The_war_to_end_all_wars%22:_World_War_I_(1914%E2%80%931918)
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#Spanish_flu
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#Russian_Revolution_and_communism
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#Between_the_wars
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#Economic_depression
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#The_rise_of_dictatorship
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#Global_war:_World_War_II_(1939%E2%80%931945)
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#The_war_in_Europe
#  -> https://en.wikipedia.org/wiki/Key_events_of_the_20th_century#Blitzkrieg
# ...

# %%
# print outcome without link
for item in sub_items:
    href = item.get_attribute("href")
    anchor = href.split("#", 1)[1]   # alles nach dem ersten '#'
    print("#" + anchor)
# Out:
# #World_at_the_beginning_of_the_century
# #%22The_war_to_end_all_wars%22:_World_War_I_(1914%E2%80%931918)
# #Spanish_flu
# #Russian_Revolution_and_communism
# #Between_the_wars
# #Economic_depression
# #The_rise_of_dictatorship
# #Global_war:_World_War_II_(1939%E2%80%931945)
# #The_war_in_Europe
# #Blitzkrieg
# #Operation_Barbarossa
# #Turning_tides
# #Operation_Overlord
# #Final_days
# #The_war_in_the_Pacific
# #Background
# #Japanese_Expansion
# #Allied_offensive
# #Final_days_2
# #The_Holocaust
# #The_Nuclear_Age_begins
# #The_post-war_world
# #The_end_of_empires:_decolonization
# #The_Cold_War_(1947%E2%80%931991)
# #War_by_proxy
# #The_space_race
# #The_end_of_the_Cold_War
# #Information_and_communications_technology
# #The_world_at_the_end_of_the_century
